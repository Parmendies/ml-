# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

pumpkins = pd.read_csv('US-pumpkins.csv')
pumpkins.head()
pumpkins = pumpkins[pumpkins['Package'].str.contains('bushel', case=True, regex=True)]

new_columns = ['Package', 'Variety', 'City Name', 'Month', 'Low Price', 'High Price', 'Date']
pumpkins = pumpkins.drop([c for c in pumpkins.columns if c not in new_columns], axis=1)

price = (pumpkins['Low Price'] + pumpkins['High Price']) / 2

month = pd.DatetimeIndex(pumpkins['Date']).month
day_of_year = pd.to_datetime(pumpkins['Date']).apply(lambda dt: (dt-datetime(dt.year,1,1)).days)
new_pumpkins = pumpkins.assign(DayOfYear=day_of_year, Month=month, Price=price)

X = pd.get_dummies(new_pumpkins['Variety']) \
        .join(new_pumpkins['Month']) \
        .join(pd.get_dummies(new_pumpkins['City Name'])) \
        .join(pd.get_dummies(new_pumpkins['Package']))
y = new_pumpkins['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline = make_pipeline(PolynomialFeatures(2), LinearRegression())
pipeline.fit(X_train,y_train)

pred = pipeline.predict(X_test)
print(X_test.keys)
mse = np.sqrt(mean_squared_error(y_test,pred))
print(f'Mean error: {mse:3.3} ({mse/np.mean(pred)*100:3.3}%)')

score = pipeline.score(X_train,y_train)
print('Model determination: ', score)
# Out:
# <bound method NDFrame.keys of       FAIRYTALE  MINIATURE  MIXED HEIRLOOM VARIETIES  PIE TYPE  Month  \
# 1571      False       True                     False     False     10
# 719       False      False                     False      True     12
# 979       False      False                     False      True     10
# 1517      False      False                     False      True     11
# 1235      False       True                     False     False     10
# ...         ...        ...                       ...       ...    ...
# 1237      False       True                     False     False      9
# 544       False       True                     False     False     10
# 77        False      False                     False      True     10
# 92        False      False                     False      True      9
# 380       False      False                     False      True     10
#
#       ATLANTA  BALTIMORE  BOSTON  CHICAGO  COLUMBIA  DETROIT  NEW YORK  \
# 1571    False      False   False    False     False    False     False
# 719     False      False   False     True     False    False     False
# 979     False      False   False    False      True    False     False
# 1517    False      False   False    False     False    False     False
# 1235    False      False   False    False     False    False      True
# ...       ...        ...     ...      ...       ...      ...       ...
# 1237    False      False   False    False     False    False      True
# 544     False      False    True    False     False    False     False
# 77      False       True   False    False     False    False     False
# 92      False       True   False    False     False    False     False
# 380     False      False    True    False     False    False     False
#
#       PHILADELPHIA  SAN FRANCISCO  ST. LOUIS  1 1/9 bushel cartons  \
# 1571         False           True      False                 False
# 719          False          False      False                  True
# 979          False          False      False                 False
# 1517         False           True      False                 False
# 1235         False          False      False                 False
# ...            ...            ...        ...                   ...
# 1237         False          False      False                 False
# 544          False          False      False                 False
# 77           False          False      False                  True
# 92           False          False      False                  True
# 380          False          False      False                 False
#
#       1 1/9 bushel crates  1/2 bushel cartons  bushel baskets  bushel cartons
# 1571                False               False            True           False
# 719                 False               False           False           False
# 979                 False               False           False            True
# 1517                False               False           False            True
# 1235                 True               False           False           False
# ...                   ...                 ...             ...             ...
# 1237                False                True           False           False
# 544                 False                True           False           False
# 77                  False               False           False           False
# 92                  False               False           False           False
# 380                  True               False           False           False
#
# [83 rows x 20 columns]>
# Mean error: 1.77 (9.13%)
# Model determination:  0.9412618706717725
# /tmp/ipykernel_3996/3407706593.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   day_of_year = pd.to_datetime(pumpkins['Date']).apply(lambda dt: (dt-datetime(dt.year,1,1)).days)
